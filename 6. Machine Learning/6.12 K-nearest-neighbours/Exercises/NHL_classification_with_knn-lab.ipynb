# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Classification and KNN with NHL data
#
# _Authors: Joseph Nelson (DC)_
#
# ---
#
# Below you will practice KNN classification on a dataset of NHL statistics.
#
# You will be predicting the `Rank` of a team from predictor variables of your choice.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# web location:
local_csv = '../data/NHL_Data_GA.csv'

# %% [markdown]
# ### 1. Load the NHL data

# %%
# A:
df= pd.read_csv("./data/NHL_Data_GA.csv")

# %% [markdown]
# ### 2. Perform any required data cleaning. Do some EDA.

# %%
# A:
df.head()
# Out:
#            Team  PTS  Rank         TOI   GF  GA  GF60  GA60   GF%    SF  ...  \
# 0  Washington10  121     1  2001:52:00  115  73  3.45  2.19  61.2  1112  ...
# 1   Vancouver11  117     1  2056:14:00   94  72  2.74  2.10  56.6  1143  ...
# 2    San Jose10  113     1  1929:54:00   90  68  2.80  2.11  57.0  1065  ...
# 3     Chicago10  112     1  2020:23:00  104  83  3.09  2.46  55.6  1186  ...
# 4   Vancouver12  111     1  2052:02:00   86  74  2.51  2.16  53.8  1078  ...
#
#     FF%    CF    CA  CF60  CA60   CF%    Sh%    Sv%   PDO   PIM
# 0  51.3  2138  1935  64.1  58.0  52.5  10.34  93.03  1034  1269
# 1  53.1  2144  1870  62.6  54.6  53.4   8.22  93.16  1014   985
# 2  50.9  1985  1876  61.7  58.3  51.4   8.45  93.46  1019  1195
# 3  58.1  2093  1572  62.2  46.7  57.1   8.77  90.44   992   966
# 4  51.0  2085  1880  61.0  55.0  52.6   7.98  93.36  1013  1049
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (90, 28)

# %%
df.isnull().sum()
# Out:
# Team    0
# PTS     0
# Rank    0
# TOI     0
# GF      0
# GA      0
# GF60    0
# GA60    0
# GF%     0
# SF      0
# SA      0
# SF60    0
# SA60    0
# SF%     0
# FF      0
# FA      0
# FF60    0
# FA60    0
# FF%     0
# CF      0
# CA      0
# CF60    0
# CA60    0
# CF%     0
# Sh%     0
# Sv%     0
# PDO     0
# PIM     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               PTS       Rank          GF          GA       GF60       GA60  \
# count   90.000000  90.000000   90.000000   90.000000  90.000000  90.000000
# mean    91.977778   2.022222   83.288889   83.288889   2.442222   2.444000
# std     12.524114   0.820767   10.376339    9.694484   0.325331   0.313522
# min     62.000000   1.000000   57.000000   64.000000   1.700000   1.730000
# 25%     82.250000   1.000000   76.000000   75.500000   2.232500   2.202500
# 50%     92.500000   2.000000   84.000000   84.000000   2.400000   2.495000
# 75%    102.000000   3.000000   90.000000   89.000000   2.600000   2.670000
# max    121.000000   3.000000  115.000000  107.000000   3.450000   3.240000
#
#              GF%           SF           SA       SF60  ...        FF%  \
# count  90.000000    90.000000    90.000000  90.000000  ...  90.000000
# mean   49.981111  1068.333333  1068.333333  31.252222  ...  49.966667
# std     4.644554    95.929047    75.514118   2.237637  ...   2.797913
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True)[['Rank']].sort_values(by='Rank', ascending=False), 
            annot=True,
           vmin=-1,
           vmax=1,
           cmap = 'coolwarm');

# %% [markdown]
# ### 3. Set up the `Rank` variable as your target. How many classes are there?

# %%
# A:
y = df['Rank']

# %%
print(y.value_counts())
# Out:
# Rank
# 3    31
# 2    30
# 1    29
# Name: count, dtype: int64

# %% [markdown]
# ### 4. What is the baseline accuracy?

# %%
# A:
most_freq_class= y.value_counts().index[0]
y.value_counts()[most_freq_class] / len(y)
# Out:
# np.float64(0.34444444444444444)

# %% [markdown]
# ### 5. Choose 4 features to be your predictor variables and set up your design matrix.

# %%
# A:
features = ['PTS', 'GF%', 'CF%', 'FF%']
X = df[features]

# %% [markdown]
# ### 6. Fit a `KNeighborsClassifier` with 1 neighbor using the target and predictors.

# %%
# A:
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ### 7. Evaluate the accuracy of your model.
# - Is it better than baseline?
# - Is it legitimate?

# %%
# A:
knn.score(X, y)
# Out:
# 1.0

# %% [markdown]
# ### 8. Create a 50-50 train-test-split of your target and predictors. Refit the KNN and assess the accuracy.

# %%
# A:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, stratify=y, random_state=1)
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)

train_accuracy = knn.score(X_train, y_train)
test_accuracy = knn.score(X_test, y_test)

print(train_accuracy, test_accuracy)
# Out:
# 1.0 0.9111111111111111

# %% [markdown]
# ### 9. Evaluate the test accuracy of a KNN where K == number of rows in the training data.

# %%
# A:
k_max = len(X_train)
knn_max = KNeighborsClassifier(n_neighbors=k_max)
knn_max.fit(X_train, y_train)
knn_max.score(X_test, y_test)
# Out:
# 0.3111111111111111

# %% [markdown]
# ### 10. Fit the KNN at values of K from 1 to the number of rows in the training data.
# - Store the test accuracy in a list.
# - Plot the test accuracy vs. the number of neighbors.

# %%
# A:
accuracies = []
k_range = range(1, len(X_train) + 1)

for k in k_range:
    knn_k = KNeighborsClassifier(n_neighbors=k)
    knn_k.fit(X_train, y_train)
    accuracies.append(knn_k.score(X_test, y_test))

plt.figure(figsize=(10, 6))
plt.plot(k_range, accuracies)
plt.xlabel('K (number of neighbors)')
plt.ylabel('Test Accuracy')
plt.title('KNN Test Accuracy vs K')
plt.show()

# %% [markdown]
# ### 11. Fit KNN across different values of K and plot the mean cross-validated accuracy with 5 folds.

# %%
# A:
from sklearn.model_selection import cross_val_score
max_k = int(len(X_train) * 4 / 5)
k_values = list(range(1, max_k + 1))
cv_mean_accuracies = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors = k)
    scores = cross_val_score(knn, X_train, y_train, cv = 5, scoring = 'accuracy')
    cv_mean_accuracies.append(np.mean(scores))

plt.figure(figsize=(10, 6))
plt.plot(k_values, cv_mean_accuracies)

plt.title('5-Fold Cross-Validated Accuracy vs. K', fontsize = 14)
plt.xlabel('Number of Neighbors (K)', fontsize = 12)
plt.ylabel('Mean CV Accuracy', fontsize = 12)
plt.show()

best_score = max(cv_mean_accuracies)
best_index = cv_mean_accuracies.index(best_score)
best_k = k_values[best_index]
print(f"Optimal K: {best_k} with Mean CV Accuracy of {best_score:.4f}")
# Out:
# Optimal K: 3 with Mean CV Accuracy of 0.9556

# %% [markdown]
# ### 12. Standardize the predictor matrix and cross-validate across the different K.
# - Plot the standardized mean cross-validated accuracy against the unstandardized. Which is better?
# - Why?

# %%
# A:
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

cv_mean_accuracies_scaled = []
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X_train_scaled, y_train, cv=5, scoring='accuracy')
    cv_mean_accuracies_scaled.append(np.mean(scores))

plt.figure(figsize=(10, 6))
plt.plot(k_values, cv_mean_accuracies, label='Unstandardized')
plt.plot(k_values, cv_mean_accuracies_scaled, label='Standardized')
plt.title('CV Accuracy vs K: Standardized vs Unstandardized', fontsize=14)
plt.xlabel('K', fontsize=12)
plt.ylabel('Mean CV Accuracy', fontsize=12)
plt.legend()
plt.show()

best_score_scaled = max(cv_mean_accuracies_scaled)
best_k_scaled = k_values[cv_mean_accuracies_scaled.index(best_score_scaled)]
print(f"Optimal K (scaled): {best_k_scaled} with accuracy {best_score_scaled:.4f}")
# Out:
# Optimal K (scaled): 5 with accuracy 0.8000

# %% [markdown]
# ## What was the best 'k'?
#
# Using `GridSearch` & `Pipeline` find the best `k` for the KNN model

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

param_grid = {
    'knn__n_neighbors': list(range(1, max_k + 1))
}

grid = GridSearchCV(pipe, param_grid, cv=5, scoring='accuracy')
grid.fit(X_train, y_train)

print(f"Best K: {grid.best_params_['knn__n_neighbors']}")
print(f"Best CV Accuracy: {grid.best_score_:.4f}")
# Out:
# Best K: 5
# Best CV Accuracy: 0.8000
